# %%
import pandas as pd

# %%
dataset=pd.read_csv("CKD.csv")

# %%
dataset
# Out:
#            age         bp sg   al   su     rbc        pc         pcc  \
# 0     2.000000  76.459948  c  3.0  0.0  normal  abnormal  notpresent
# 1     3.000000  76.459948  c  2.0  0.0  normal    normal  notpresent
# 2     4.000000  76.459948  a  1.0  0.0  normal    normal  notpresent
# 3     5.000000  76.459948  d  1.0  0.0  normal    normal  notpresent
# 4     5.000000  50.000000  c  0.0  0.0  normal    normal  notpresent
# ..         ...        ... ..  ...  ...     ...       ...         ...
# 394  51.492308  70.000000  a  0.0  0.0  normal    normal  notpresent
# 395  51.492308  70.000000  c  0.0  2.0  normal    normal  notpresent
# 396  51.492308  70.000000  c  3.0  0.0  normal    normal  notpresent
# 397  51.492308  90.000000  a  0.0  0.0  normal    normal  notpresent
# 398  51.492308  80.000000  a  0.0  0.0  normal    normal  notpresent
#
#              ba         bgr  ...        pcv            wc        rc  htn   dm  \
# 0    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 1    notpresent  148.112676  ...  34.000000  12300.000000  4.705597   no   no
# 2    notpresent   99.000000  ...  34.000000   8408.191126  4.705597   no   no
# 3    notpresent  148.112676  ...  38.868902   8408.191126  4.705597   no   no
# 4    notpresent  148.112676  ...  36.000000  12400.000000  4.705597   no   no
# ..          ...         ...  ...        ...           ...       ...  ...  ...
# 394  notpresent  219.000000  ...  37.000000   9800.000000  4.400000   no   no
# 395  notpresent  220.000000  ...  27.000000   8408.191126  4.705597  yes  yes
# 396  notpresent  110.000000  ...  26.000000   9200.000000  3.400000  yes  yes
# 397  notpresent  207.000000  ...  38.868902   8408.191126  4.705597  yes  yes
# 398  notpresent  100.000000  ...  53.000000   8500.000000  4.900000   no   no
#
#      cad  appet    pe  ane classification
# 0     no    yes   yes   no            yes
# 1     no    yes  poor   no            yes
# 2     no    yes  poor   no            yes
# 3     no    yes  poor  yes            yes
# 4     no    yes  poor   no            yes
# ..   ...    ...   ...  ...            ...
# 394   no    yes  poor   no            yes
# 395   no    yes  poor  yes            yes
# 396   no   poor  poor   no            yes
# 397   no    yes  poor  yes            yes
# 398   no    yes  poor   no             no
#
# [399 rows x 25 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
indep=dataset[['age', 'bp', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hrmo', 'pcv',
       'wc', 'rc', 'sg_b', 'sg_c', 'sg_d', 'sg_e', 'rbc_normal', 'pc_normal',
       'pcc_present', 'ba_present', 'htn_yes', 'dm_yes', 'cad_yes',
       'appet_yes', 'pe_yes', 'ane_yes']]

# %%
dep=dataset[['classification_yes']]

# %%
dataset[['classification_yes']].value_counts()
# Out:
# classification_yes
# 1                     249
# 0                     150
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(indep,dep,test_size=0.30,random_state= 0,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
param_grid={ 'criterion' : ['gini', 'entropy', 'log_loss'],
             'splitter' : ['best', 'random'], 'max_depth': [5,6]
                }
grid=GridSearchCV(DecisionTreeClassifier(),param_grid,refit=True,n_jobs=-1,verbose=3,scoring='f1_weighted')
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [5, 6], 'splitter': ['best', 'random']},
#              scoring='f1_weighted', verbose=3)

# %%
re=grid.cv_results_

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.054381      0.066603         0.034424        0.011742
# 1        0.012500      0.006250         0.021877        0.007655
# 2        0.009377      0.007657         0.018751        0.006248
# 3        0.009374      0.007654         0.024286        0.011268
# 4        0.003208      0.003981         0.029661        0.008630
# 5        0.004569      0.006195         0.028128        0.006250
# 6        0.012502      0.006251         0.021876        0.007657
# 7        0.006251      0.007656         0.028127        0.006252
# 8        0.011619      0.006055         0.024385        0.011437
# 9        0.005170      0.005734         0.027770        0.014858
# 10       0.007037      0.007158         0.027947        0.006170
# 11       0.009375      0.012499         0.025004        0.007657
#
#    param_criterion param_max_depth param_splitter  \
# 0             gini               5           best
# 1             gini               5         random
# 2             gini               6           best
# 3             gini               6         random
# 4          entropy               5           best
# 5          entropy               5         random
# 6          entropy               6           best
# 7          entropy               6         random
# 8         log_loss               5           best
# 9         log_loss               5         random
# 10        log_loss               6           best
# 11        log_loss               6         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'gini', 'max_depth': 5, 'splitte...           0.911692
# 1   {'criterion': 'gini', 'max_depth': 5, 'splitte...           0.982221
# 2   {'criterion': 'gini', 'max_depth': 6, 'splitte...           0.929144
# 3   {'criterion': 'gini', 'max_depth': 6, 'splitte...           0.982221
# 4   {'criterion': 'entropy', 'max_depth': 5, 'spli...           0.964286
# 5   {'criterion': 'entropy', 'max_depth': 5, 'spli...           0.964286
# 6   {'criterion': 'entropy', 'max_depth': 6, 'spli...           0.964286
# 7   {'criterion': 'entropy', 'max_depth': 6, 'spli...           0.929513
# 8   {'criterion': 'log_loss', 'max_depth': 5, 'spl...           0.982051
# 9   {'criterion': 'log_loss', 'max_depth': 5, 'spl...           0.893717
# 10  {'criterion': 'log_loss', 'max_depth': 6, 'spl...           1.000000
# 11  {'criterion': 'log_loss', 'max_depth': 6, 'spl...           0.945469
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.927778           0.894531           0.945469
# 1            0.982051           0.876368           0.964286
# 2            0.909115           0.894531           0.927778
# 3            0.964286           0.928571           0.964572
# 4            0.963889           0.876984           0.909115
# 5            0.945469           0.911692           0.963889
# 6            0.963889           0.859355           0.909115
# 7            0.947015           0.946663           0.982221
# 8            0.945469           0.876984           0.927778
# 9            0.911105           0.982051           0.964286
# 10           0.945469           0.894531           0.909115
# 11           0.982051           0.911692           0.964286
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.981728         0.932240        0.029961               11
# 1            0.981728         0.957331        0.041059                2
# 2            0.926494         0.917412        0.013564               12
# 3            0.946014         0.957133        0.018305                3
# 4            0.981728         0.939200        0.039556                9
# 5            0.981728         0.953413        0.023805                5
# 6            0.981728         0.935675        0.045312               10
# 7            1.000000         0.961082        0.025938                1
# 8            0.981728         0.942802        0.039040                7
# 9            0.981728         0.946577        0.037041                6
# 10           0.963636         0.942550        0.037888                8
# 11           0.981728         0.957045        0.026374                4

# %%
bestParams=grid.best_params_
print("Best Parameter {} ".format(bestParams))
# Out:
# Best Parameter {'criterion': 'entropy', 'max_depth': 6, 'splitter': 'random'}

# %%
gridPred=grid.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,gridPred)
print(cm)
# Out:
# [[43  2]
#  [ 2 73]]

# %%
from sklearn.metrics import classification_report
clf=classification_report(y_test,gridPred)
print(clf)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        45
#            1       0.97      0.97      0.97        75
#
#     accuracy                           0.97       120
#    macro avg       0.96      0.96      0.96       120
# weighted avg       0.97      0.97      0.97       120

# %%
from sklearn.metrics import f1_score
fscore=f1_score(y_test,gridPred,average='weighted')
print(fscore)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,gridPred,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'criterion': 'entropy', 'max_depth': 6, 'splitter': 'random'}: 0.9666666666666667

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(x_test)[:,1])
#predict the probability of +ve class in x_test dataset
# Out:
# 0.9831111111111112

# %%
age=int(input("Age : "))
bp=float(input("BP : "))
al=float(input("AL : "))
su=float(input("su : "))
bgr=float(input("bgr : "))
bu=float(input("bu : "))
sc=float(input("sc : "))
sod=float(input("sod : "))
pot=float(input("pot : "))
hrmo=float(input("hrmo : "))
pcv=int(input("pcv : "))
wc=int(input("wc : "))
rc=int(input("rc : "))
sg_b=int(input("sg_b : "))
sg_c=int(input("sg_c : "))
sg_d=int(input("sg_d : "))
sg_e=int(input("sg_e : "))
rbc_normal=int(input("rbc_normal : "))
pc_normal=int(input("pc_normal : "))
pcc_present=int(input("pcc_present : "))
ba_present=int(input("ba_present : "))
htn_yes=int(input("htn_yes : "))
dm_yes=int(input("dm_yes : "))
cad_yes=int(input("cad_yes : "))
appet_yes=int(input("appet_yes : "))
pe_yes=int(input("pe_yes : "))
ane_yes=int(input("Ane_yes : "))
# Out:
# Age : 4
# BP : 3.2
# AL : 6.7
# su : 4.5
# bgr : 6.7
# bu : 8.2
# sc : 4.87
# sod : 4.56
# pot : 2.89
# hrmo : 7.45
# pcv : 2
# wc : 3
# rc : 4
# sg_b : 1
# sg_c : 0
# sg_d : 1
# sg_e : 0
# rbc_normal : 1
# pc_normal : 0
# pcc_present : 1
# ba_present : 0
# htn_yes : 1
# dm_yes : 0
# cad_yes : 1
# appet_yes : 0
# pe_yes : 0
# Ane_yes : 1

# %%
futurePred=grid.predict([[age,bp,al,su, bgr, bu, sc, sod, pot, hrmo, pcv,
       wc, rc, sg_b, sg_c, sg_d, sg_e, rbc_normal, pc_normal,
       pcc_present, ba_present, htn_yes, dm_yes, cad_yes,
       appet_yes, pe_yes, ane_yes]])
print("Future Predictions : {} ".format(futurePred))
# Out:
# Future Predictions : [1]
